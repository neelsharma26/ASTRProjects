# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([3000, 4500, 6000, 8000, 10000, 17000], [0.01, 0.1, 1, 10, 100, 1000], 'ro')

plt.ylabel('Luminosity', {'fontname': 'Times New Roman', 'fontsize': 14})
plt.xlabel('Temperature', {'fontname': 'Times New Roman', 'fontsize': 14})

plt.ylim(0.001, 1000000)
plt.xlim(2000, 30000)
plt.xticks()
plt.title('The Hertzprung-Russell (HR) Diagram Practise', {'fontname': 'Times New Roman', 'fontsize': 18})
def mouse_event(event):
    print('x: {} and y: {}'.format(event.xdata, event.ydata))

plt.gca().invert_xaxis()

plt.xscale('log')
plt.yscale('log')

plt.show()
